# %%
import unittest
from test_resume_prompt import ResumePromptTests
suite = unittest.defaultTestLoader.loadTestsFromTestCase(ResumePromptTests)
result = unittest.TextTestRunner(verbosity=2).run(suite)
assert result.wasSuccessful(), result
# Out:
# test_prompt_stays_factual_and_does_not_overstate (test_resume_prompt.ResumePromptTests.test_prompt_stays_factual_and_does_not_overstate) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.003s
#
# OK

# %%
import resume_processor as rp
prompt = rp.build_resume_prompt('Recruiter wants a Python/ML engineer', 'Experience: Python developer at Example Corp')
assert 'preserve the existing facts' in prompt, prompt
assert 'Do not invent new companies' in prompt, prompt
assert 'aggressively emphasize' not in prompt
assert 'AI-focused engineer' not in prompt
print('prompt checks passed')
# Out:
# prompt checks passed
